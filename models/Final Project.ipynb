# %%
import os
import cv2
import numpy as np
import joblib
import time
from skimage.feature import hog, graycomatrix, graycoprops
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# --- Configuration ---
INPUT_FOLDER = "images"  # Folder to read training images from
MODEL_PATH = "wildlife_cluster_model.pkl" # File to save the new model to

# --- Constants (MUST be identical to prediction script) ---
GRID_W = 100  # 800 / 8
GRID_H = 75   # 600 / 8
TARGET_ASPECT_RATIO = 4.0 / 3.0
LBP_RADIUS = 1
LBP_POINTS = 8 * LBP_RADIUS
# Ensure LBP config matches our manual CLBP function
assert LBP_RADIUS == 1 and LBP_POINTS == 8, "CLBP implementation is specific to R=1, P=8"


# --- Image Preprocessing ---
def process_image_for_training(path: str) -> np.ndarray | None:
    """
    Loads an image and processes it according to the strict 4:3 / 800x600 rules.
    - Enforces 4:3 aspect ratio by center-cropping.
    - Scales down large images.
    - Discards small images.
    - Returns a 3-channel HSV image.
    """
    img = cv2.imread(path)
    if img is None:
        print(f"Warning: Could not read image at {path}")
        return None
    
    h, w, _ = img.shape
    current_aspect_ratio = w / h
    
    # a. Crop to 4:3 aspect ratio if it's not already correct
    if not np.isclose(current_aspect_ratio, TARGET_ASPECT_RATIO):
        if current_aspect_ratio > TARGET_ASPECT_RATIO: # Image is wider than 4:3
            new_w = int(TARGET_ASPECT_RATIO * h)
            x_start = (w - new_w) // 2
            img = img[:, x_start:x_start + new_w]
        else: # Image is taller than 4:3
            new_h = int(w / TARGET_ASPECT_RATIO)
            y_start = (h - new_h) // 2
            img = img[y_start:y_start + new_h, :]
    
    # b. Scale down if larger than 800x600
    h, w, _ = img.shape
    if w > 800 or h > 600:
        img = cv2.resize(img, (800, 600), interpolation=cv2.INTER_AREA)

    # c. Do not scale up if smaller than 800x600 (discard)
    h, w, _ = img.shape
    if w < 800 or h < 600:
        # print(f"Info: Discarding small image: {path} ({w}x{h})")
        return None
        
    # Convert to HSV color space for feature extraction
    return cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# --- CLBP Helper Function (with dtype fix) ---
def compute_clbp_components(image: np.ndarray) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Calculates the Completed LBP (CLBP) components: S, M, and C.
    This implementation is for R=1, P=8.
    """
    img_float = image.astype(np.float64)
    padded = np.pad(img_float, (1, 1), 'edge')
    
    center = padded[1:-1, 1:-1]
    neighbors = [
        padded[ :-2,  :-2], padded[ :-2, 1:-1], padded[ :-2, 2:  ],
        padded[1:-1, 2:  ], padded[2:  , 2:  ], padded[2:  , 1:-1],
        padded[2:  ,  :-2], padded[1:-1,  :-2]
    ]
    
    diffs = [n - center for n in neighbors]
    mags = [np.abs(d) for d in diffs]
    
    # --- FIX: Use a larger intermediate dtype (e.g., int64) to prevent overflow ---
    clbp_s = np.zeros_like(center, dtype=np.int64) 
    for i in range(LBP_POINTS):
        clbp_s += ((diffs[i] >= 0) * (2**i))
        
    mean_mag = np.mean([m.ravel() for m in mags])
    
    clbp_m = np.zeros_like(center, dtype=np.int64)
    for i in range(LBP_POINTS):
        clbp_m += ((mags[i] >= mean_mag) * (2**i))

    mean_center = np.mean(center)
    clbp_c = (center >= mean_center).astype(np.uint8)
    
    # --- FIX: Cast back to uint8 on return ---
    return clbp_s.astype(np.uint8), clbp_m.astype(np.uint8), clbp_c

# --- Feature Extraction (using CLBP + HOG) ---
def extract_features_from_cell(cell: np.ndarray) -> np.ndarray:
    """
    Extracts features from a single 100x75 3-channel HSV grid cell.
    - Extracts Color Features (mean/std) from H and S channels.
    - Extracts Texture Features (mean/std, CLBP, GLCM, HOG, Canny) from V channel.
    """
    features = []
    h, s, v = cv2.split(cell)
    
    # 1. Color Features
    features.append(np.mean(h))
    features.append(np.std(h))
    features.append(np.mean(s))
    features.append(np.std(s))

    # 2. Statistical Features (from V)
    features.append(np.mean(v))
    features.append(np.std(v))
    
    v_uint8 = v.astype(np.uint8)

    # 3. Completed LBP (CLBP) Histograms (from V channel)
    clbp_s, clbp_m, clbp_c = compute_clbp_components(v_uint8)
    
    # a. CLBP-S Histogram (Sign) - 256 bins
    hist_s, _ = np.histogram(clbp_s.ravel(), bins=np.arange(0, 257), density=True)
    features.extend(hist_s)
    
    # b. CLBP-M Histogram (Magnitude) - 256 bins
    hist_m, _ = np.histogram(clbp_m.ravel(), bins=np.arange(0, 257), density=True)
    features.extend(hist_m)
    
    # c. CLBP-C Histogram (Center) - 2 bins
    hist_c, _ = np.histogram(clbp_c.ravel(), bins=np.arange(0, 3), density=True)
    features.extend(hist_c)

    # 4. GLCM Texture Features (from V)
    glcm = graycomatrix(v_uint8, 
                        distances=[1], 
                        angles=[0, np.pi/4, np.pi/2, 3*np.pi/4],
                        levels=256, symmetric=True, normed=True)
    
    features.extend([
        np.mean(graycoprops(glcm, 'contrast')),
        np.mean(graycoprops(glcm, 'dissimilarity')),
        np.mean(graycoprops(glcm, 'homogeneity')),
        np.mean(graycoprops(glcm, 'energy')),
        np.mean(graycoprops(glcm, 'correlation'))
    ])
    
    # --- 5. NEW: HOG Features (from V channel) ---
    # We use larger cells (16x16) to keep the feature vector size manageable.
    # On a 100x75 cell, this produces a 540-feature vector.
    hog_features = hog(v_uint8, 
                       orientations=9, 
                       pixels_per_cell=(16, 16),
                       cells_per_block=(2, 2), 
                       block_norm='L2-Hys', 
                       feature_vector=True)
    features.extend(hog_features)

    # --- 6. Edge Density Feature (from V channel) ---
    edges = cv2.Canny(v_uint8, 50, 150)
    features.append(np.sum(edges > 0) / v.size)
    
    return np.array(features)

def extract_features_from_image(img: np.ndarray) -> np.ndarray:
    """
    Extracts features from all 64 cells in a single HSV image.
    """
    features_list = []
    for y in range(0, img.shape[0], GRID_H):
        for x in range(0, img.shape[1], GRID_W):
            cell = img[y:y+GRID_H, x:x+GRID_W]
            features_list.append(extract_features_from_cell(cell))
    return np.vstack(features_list)

# --- Main Training Logic ---
if __name__ == "__main__":
    
    if not os.path.exists(INPUT_FOLDER):
        print(f"Error: Input folder not found at '{INPUT_FOLDER}'")
        exit()

    print(f"Starting feature extraction from '{INPUT_FOLDER}'...")
    start_time = time.time()
    
    # 1. Find all image paths
    image_paths = [
        os.path.join(INPUT_FOLDER, f) for f in os.listdir(INPUT_FOLDER)
        if f.lower().endswith(('png', 'jpg', 'jpeg'))
    ]
    
    if not image_paths:
        print(f"Error: No images found in '{INPUT_FOLDER}'.")
        exit()
        
    print(f"Found {len(image_paths)} images.")
    
    # 2. Extract features from all images
    all_features_list = []
    for i, path in enumerate(image_paths):
        print(f"  Processing image {i+1}/{len(image_paths)}: {path}")
        processing_img = process_image_for_training(path)
        
        if processing_img is not None:
            # features shape will be (64, 1066)
            features = extract_features_from_image(processing_img)
            all_features_list.append(features)
        else:
            print(f"    -> Skipping {path} (preprocessing failed).")

    if not all_features_list:
        print("Error: No valid images were processed. Exiting.")
        exit()
        
    # Create the master data array X
    X = np.vstack(all_features_list)
    
    extraction_time = time.time() - start_time
    print(f"\nFeature extraction complete in {extraction_time:.2f}s")
    print(f"Extracted {X.shape[1]} features from {X.shape[0]} total cells.")
    
    # 3. Scale the features
    print("Scaling features...")
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    
    # 4. Find the optimal k for KMeans
    print("Finding optimal k using Silhouette Score...")
    silhouette_scores = {}
    k_range = range(2, 8) 
    
    for k in k_range:
        print(f"  Testing k={k}...")
        kmeans_temp = KMeans(n_clusters=k, random_state=42, n_init=10)
        labels = kmeans_temp.fit_predict(X_scaled)
        
        # Sample for silhouette score if data is large
        if X_scaled.shape[0] > 10000:
            print("    (Calculating score on a sample of 10k points)")
            np.random.seed(42)
            sample_indices = np.random.choice(X_scaled.shape[0], 10000, replace=False)
            score = silhouette_score(X_scaled[sample_indices], labels[sample_indices])
        else:
            score = silhouette_score(X_scaled, labels)
            
        silhouette_scores[k] = score
        print(f"  -> Silhouette Score: {score:.4f}")

    # Get the k with the highest score
    best_k = max(silhouette_scores, key=silhouette_scores.get)
    print(f"\nBest k found: {best_k} (Score: {silhouette_scores[best_k]:.4f})")
    
    # 5. Train the final model
    print(f"Training final model with k={best_k}...")
    final_kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=10)
    final_kmeans.fit(X_scaled)
    
    # 6. Save the scaler and the k-means model together
    print(f"Saving model to {MODEL_PATH}...")
    models_to_save = {
        'scaler': scaler,
        'kmeans': final_kmeans
    }
    joblib.dump(models_to_save, MODEL_PATH)
    
    print("\n--- Training Complete ---")
    print(f"Model (scaler + kmeans) saved successfully to '{MODEL_PATH}'.")
    print("You can now run the prediction script.")
# Out:
# Starting feature extraction from 'images'...
# Found 465 images.
#   Processing image 1/465: images/RIMG0051.JPG
#   Processing image 2/465: images/CIMG0496(1).JPG
#   Processing image 3/465: images/CIMG0569.JPG
#   Processing image 4/465: images/CIMG0233.JPG
#     -> Skipping images/CIMG0233.JPG (preprocessing failed).
#   Processing image 5/465: images/CIMG0555.JPG
#   Processing image 6/465: images/RIMG0079.JPG
#   Processing image 7/465: images/CIMG0757.JPG
#   Processing image 8/465: images/CIMG0067(2).JPG
#   Processing image 9/465: images/IMG_20180726_154742802.jpg
#   Processing image 10/465: images/CIMG0958.JPG
#   Processing image 11/465: images/CIMG0179.JPG
#   Processing image 12/465: images/IMG_20250709_164054571_HDR~2.jpg
#   Processing image 13/465: images/CIMG0162(1).JPG
#   Processing image 14/465: images/IMG_3858.JPG
#     -> Skipping images/IMG_3858.JPG (preprocessing failed).
#   Processing image 15/465: images/DSC02847.JPG
#   Processing image 16/465: images/CIMG0186.JPG
#   Processing image 17/465: images/CIMG0192.JPG
#   Processing image 18/465: images/p12.jpg
#   Processing image 19/465: images/IMG_3332.JPG
#     -> Skipping images/IMG_3332.JPG (preprocessing failed).
#   Processing image 20/465: images/CIMG0139~2.JPG
#   Processing image 21/465: images/CIMG0434.JPG
#   Processing image 22/465: images/CIMG0408.JPG
#   Processing image 23/465: images/CIMG0120(2).JPG
#   Processing image 24/465: images/RIMG0124.JPG
#   Processing image 25/465: images/CIMG0129(1).JPG
#   Processing image 26/465: images/RIMG1945.JPG
#   Processing image 27/465: images/CIMG0150.JPG
#   Processing image 28/465: images/CIMG0144.JPG
#   Processing image 29/465: images/CIMG0178.JPG
#   Processing image 30/465: images/CIMG0318~2.JPG
#   Processing image 31/465: images/IMG_20250705_125546309.jpg
#   Processing image 32/465: images/CIMG0030.JPG
#   Processing image 33/465: images/CIMG0018.JPG
#   Processing image 34/465: images/CIMG0108~2(1).JPG
#   Processing image 35/465: images/CIMG0158(1).JPG
#   Processing image 36/465: images/CIMG0232.JPG
#   Processing image 37/465: images/RIMG0050.JPG
#   Processing image 38/465: images/CIMG0218.JPG
#     -> Skipping images/CIMG0218.JPG (preprocessing failed).
#   Processing image 39/465: images/IMG_20250709_163052484_HDR~2.jpg
#   Processing image 40/465: images/CIMG0569(1).JPG
#   Processing image 41/465: images/CIMG0595.JPG
#   Processing image 42/465: images/CIMG0608.JPG
#   Processing image 43/465: images/CIMG0506(1).JPG
#   Processing image 44/465: images/CIMG1270.JPG
#   Processing image 45/465: images/IMG_4194(1).JPG
#   Processing image 46/465: images/CIMG0152.JPG
#   Processing image 47/465: images/IMG_20250709_164031681_HDR~2.jpg
#   Processing image 48/465: images/CIMG0191.JPG
#   Processing image 49/465: images/CIMG0378.JPG
#   Processing image 50/465: images/CIMG0422.JPG
#   Processing image 51/465: images/CIMG0344.JPG
#   Processing image 52/465: images/CIMG0083(1).JPG
#   Processing image 53/465: images/29032008693.jpg
#   Processing image 54/465: images/p10.jpg
#   Processing image 55/465: images/IMG_1724.JPG
#   Processing image 56/465: images/CIMG0190.JPG
#   Processing image 57/465: images/CIMG0147.JPG
#   Processing image 58/465: images/IMG_3682.JPG
#   Processing image 59/465: images/CIMG0153.JPG
#   Processing image 60/465: images/CIMG0980(1).JPG
#   Processing image 61/465: images/CIMG0594.JPG
#   Processing image 62/465: images/CIMG0580.JPG
#   Processing image 63/465: images/CIMG0225.JPG
#   Processing image 64/465: images/CIMG0210(1).JPG
#   Processing image 65/465: images/RIMG0047.JPG
#   Processing image 66/465: images/IMG_20250705_142522.jpg
#   Processing image 67/465: images/CIMG0221.JPG
#   Processing image 68/465: images/CIMG0342~2.JPG
#   Processing image 69/465: images/CIMG0209.JPG
#     -> Skipping images/CIMG0209.JPG (preprocessing failed).
#   Processing image 70/465: images/CIMG0584.JPG
#   Processing image 71/465: images/CIMG0228(1).JPG
#     -> Skipping images/CIMG0228(1).JPG (preprocessing failed).
#   Processing image 72/465: images/CIMG0579(1).JPG
#   Processing image 73/465: images/IMG_3686.JPG
#     -> Skipping images/IMG_3686.JPG (preprocessing failed).
#   Processing image 74/465: images/CIMG0143.JPG
#   Processing image 75/465: images/CIMG0126~2.JPG
#   Processing image 76/465: images/CIMG0180.JPG
#   Processing image 77/465: images/CIMG0427.JPG
#   Processing image 78/465: images/CIMG0382~2.JPG
#   Processing image 79/465: images/IMG_20221207_075613681.jpg
#   Processing image 80/465: images/IMG_3334.JPG
#     -> Skipping images/IMG_3334.JPG (preprocessing failed).
#   Processing image 81/465: images/29032008696.jpg
#   Processing image 82/465: images/CIMG0426.JPG
#   Processing image 83/465: images/CIMG0432.JPG
#   Processing image 84/465: images/CIMG0181.JPG
#   Processing image 85/465: images/CIMG0142.JPG
#   Processing image 86/465: images/IMG_3687.JPG
#   Processing image 87/465: images/RIMG0081.JPG
#   Processing image 88/465: images/CIMG0585.JPG
#   Processing image 89/465: images/CIMG0208.JPG
#   Processing image 90/465: images/CIMG0234.JPG
#   Processing image 91/465: images/CIMG0546.JPG
#   Processing image 92/465: images/CIMG0236.JPG
#   Processing image 93/465: images/CIMG0578.JPG
#   Processing image 94/465: images/CIMG0593.JPG
#   Processing image 95/465: images/CIMG0034.JPG
#   Processing image 96/465: images/CIMG0975.JPG
#   Processing image 97/465: images/CIMG0140.JPG
#   Processing image 98/465: images/CIMG0154.JPG
#   Processing image 99/465: images/CIMG0168.JPG
#   Processing image 100/465: images/CIMG0100~2.JPG
#   Processing image 101/465: images/CIMG0118(2).JPG
#   Processing image 102/465: images/CIMG0197.JPG
#   Processing image 103/465: images/CIMG0342.JPG
#   Processing image 104/465: images/p17.jpg
#   Processing image 105/465: images/CIMG0757(2).JPG
#   Processing image 106/465: images/CIMG0394.JPG
#   Processing image 107/465: images/IMG_3337.JPG
#     -> Skipping images/IMG_3337.JPG (preprocessing failed).
#   Processing image 108/465: images/p16.jpg
#   Processing image 109/465: images/CIMG0225~2.JPG
#   Processing image 110/465: images/CIMG0431.JPG
#   Processing image 111/465: images/29032008695.jpg
#   Processing image 112/465: images/CIMG0196.JPG
#   Processing image 113/465: images/IMG_3653.JPG
#     -> Skipping images/IMG_3653.JPG (preprocessing failed).
#   Processing image 114/465: images/CIMG0155.JPG
#   Processing image 115/465: images/CIMG0141.JPG
#   Processing image 116/465: images/CIMG0035.JPG
#   Processing image 117/465: images/CIMG0135(1).JPG
#   Processing image 118/465: images/CIMG0579.JPG
#   Processing image 119/465: images/CIMG0119~2.JPG
#   Processing image 120/465: images/26102010062.jpg
#   Processing image 121/465: images/CIMG0428(1).JPG
#   Processing image 122/465: images/CIMG0126.JPG
#   Processing image 123/465: images/IMG_4198.JPG
#   Processing image 124/465: images/IMG_4173.JPG
#   Processing image 125/465: images/CIMG0107~2.JPG
#   Processing image 126/465: images/CIMG0442.JPG
#   Processing image 127/465: images/IMG_3393.JPG
#   Processing image 128/465: images/IMG_3387.JPG
#   Processing image 129/465: images/CIMG0330.JPG
#   Processing image 130/465: images/IMG_3378.JPG
#   Processing image 131/465: images/CIMG0495.JPG
#   Processing image 132/465: images/CIMG0494.JPG
#   Processing image 133/465: images/IMG-20140317-WA0001.jpg
#     -> Skipping images/IMG-20140317-WA0001.jpg (preprocessing failed).
#   Processing image 134/465: images/IMG_3386.JPG
#   Processing image 135/465: images/CIMG0319.JPG
#   Processing image 136/465: images/IMG_4172.JPG
#   Processing image 137/465: images/CIMG0127.JPG
#   Processing image 138/465: images/CIMG0084.JPG
#   Processing image 139/465: images/CIMG0047.JPG
#   Processing image 140/465: images/CIMG0537.JPG
#   Processing image 141/465: images/CIMG0253.JPG
#   Processing image 142/465: images/CIMG0001~2.JPG
#   Processing image 143/465: images/CIMG0079.JPG
#   Processing image 144/465: images/p9.jpg
#   Processing image 145/465: images/CIMG0152(1).JPG
#   Processing image 146/465: images/CIMG0086.JPG
#   Processing image 147/465: images/CIMG0092.JPG
#   Processing image 148/465: images/CIMG0119.JPG
#   Processing image 149/465: images/CIMG0123(1).JPG
#   Processing image 150/465: images/CIMG0125.JPG
#   Processing image 151/465: images/IMG_4164.JPG
#   Processing image 152/465: images/IMG_3637.JPG
#   Processing image 153/465: images/IMG_4158.JPG
#   Processing image 154/465: images/CIMG0134(2).JPG
#   Processing image 155/465: images/CIMG0333.JPG
#   Processing image 156/465: images/CIMG0079~2.JPG
#   Processing image 157/465: images/CIMG0140(1).JPG
#   Processing image 158/465: images/IMG_3409.JPG
#     -> Skipping images/IMG_3409.JPG (preprocessing failed).
#   Processing image 159/465: images/CIMG0496.JPG
#   Processing image 160/465: images/IMG_3347.JPG
#   Processing image 161/465: images/CIMG0115(1).JPG
#   Processing image 162/465: images/IMG_20250705_121136381~2.jpg
#   Processing image 163/465: images/CIMG0079~3.JPG
#   Processing image 164/465: images/CIMG0068(1).JPG
#   Processing image 165/465: images/IMG_3385.JPG
#   Processing image 166/465: images/IMG_20250627_105023208.jpg
#   Processing image 167/465: images/IMG_4165.JPG
#   Processing image 168/465: images/IMG_4171.JPG
#   Processing image 169/465: images/CIMG0642.JPG
#   Processing image 170/465: images/CIMG0124.JPG
#   Processing image 171/465: images/CIMG0130.JPG
#   Processing image 172/465: images/IMG_3839.JPG
#     -> Skipping images/IMG_3839.JPG (preprocessing failed).
#   Processing image 173/465: images/CIMG0118.JPG
#   Processing image 174/465: images/p8.jpg
#   Processing image 175/465: images/IMG_20180726_154804552.jpg
#   Processing image 176/465: images/CIMG0078.JPG
#   Processing image 177/465: images/CIMG0138~2.JPG
#   Processing image 178/465: images/CIMG0064(1).JPG
#   Processing image 179/465: images/CIMG0242.JPG
#   Processing image 180/465: images/CIMG0256.JPG
#   Processing image 181/465: images/IMG_3550.JPG
#   Processing image 182/465: images/CIMG0054.JPG
#   Processing image 183/465: images/CIMG0083.JPG
#   Processing image 184/465: images/CIMG0097.JPG
#   Processing image 185/465: images/CIMG0134.JPG
#   Processing image 186/465: images/CIMG0120.JPG
#   Processing image 187/465: images/CIMG0108.JPG
#   Processing image 188/465: images/CIMG0914(1).JPG
#   Processing image 189/465: images/IMG_4175.JPG
#   Processing image 190/465: images/IMG_2510.JPG
#   Processing image 191/465: images/CIMG0131~2(1).JPG
#   Processing image 192/465: images/IMG_3395.JPG
#   Processing image 193/465: images/CIMG0099~2.JPG
#   Processing image 194/465: images/CIMG0493.JPG
#   Processing image 195/465: images/CIMG0064~2.JPG
#   Processing image 196/465: images/CIMG0487.JPG
#   Processing image 197/465: images/CIMG0021~2.JPG
#   Processing image 198/465: images/IMG_3418.JPG
#   Processing image 199/465: images/IMG_3419.JPG
#     -> Skipping images/IMG_3419.JPG (preprocessing failed).
#   Processing image 200/465: images/CIMG0486.JPG
#   Processing image 201/465: images/IMG_3394.JPG
#   Processing image 202/465: images/CIMG0118~2.JPG
#   Processing image 203/465: images/IMG_4174.JPG
#   Processing image 204/465: images/CIMG0121.JPG
#   Processing image 205/465: images/CIMG0171(2).JPG
#   Processing image 206/465: images/CIMG0135.JPG
#   Processing image 207/465: images/CIMG0914.jpg
#   Processing image 208/465: images/CIMG0096.JPG
#   Processing image 209/465: images/IMG_3747.JPG
#     -> Skipping images/IMG_3747.JPG (preprocessing failed).
#   Processing image 210/465: images/CIMG0144~3.JPG
#     -> Skipping images/CIMG0144~3.JPG (preprocessing failed).
#   Processing image 211/465: images/CIMG0381~2.JPG
#   Processing image 212/465: images/IMG_20180726_154949063_BURST001.jpg
#   Processing image 213/465: images/CIMG0117(1).JPG
#   Processing image 214/465: images/CIMG0160~2.JPG
#   Processing image 215/465: images/CIMG0531.JPG
#   Processing image 216/465: images/CIMG0224~2.JPG
#   Processing image 217/465: images/CIMG0257.JPG
#   Processing image 218/465: images/Photo0044.jpg
#   Processing image 219/465: images/CIMG0127~2.JPG
#   Processing image 220/465: images/CIMG0080.JPG
#   Processing image 221/465: images/CIMG0123.JPG
#   Processing image 222/465: images/CIMG0137.JPG
#   Processing image 223/465: images/CIMG0365(1).JPG
#   Processing image 224/465: images/IMG_4176.JPG
#   Processing image 225/465: images/IMG_20180401_143225122_HDR.jpg
#   Processing image 226/465: images/CIMG0484.JPG
#   Processing image 227/465: images/CIMG0490.JPG
#   Processing image 228/465: images/IMG_3369.JPG
#     -> Skipping images/IMG_3369.JPG (preprocessing failed).
#   Processing image 229/465: images/IMG_3368.JPG
#   Processing image 230/465: images/CIMG0491.JPG
#   Processing image 231/465: images/CIMG0485.JPG
#   Processing image 232/465: images/CIMG0320.JPG
#   Processing image 233/465: images/CIMG0081.JPG
#   Processing image 234/465: images/CIMG0095.JPG
#   Processing image 235/465: images/IMG_4182(1).JPG
#   Processing image 236/465: images/IMG_3403(1).JPG
#   Processing image 237/465: images/CIMG0056.JPG
#   Processing image 238/465: images/CIMG0103~2.JPG
#   Processing image 239/465: images/CIMG0146~2.JPG
#   Processing image 240/465: images/RIMG1328.JPG
#   Processing image 241/465: images/CIMG0268.JPG
#   Processing image 242/465: images/CIMG0254.JPG
#   Processing image 243/465: images/CIMG1147.JPG
#   Processing image 244/465: images/DSC00343.JPG
#   Processing image 245/465: images/CIMG0271.JPG
#   Processing image 246/465: images/CIMG0265.JPG
#   Processing image 247/465: images/CIMG0012~2.JPG
#   Processing image 248/465: images/CIMG0073.JPG
#   Processing image 249/465: images/CIMG0067.JPG
#   Processing image 250/465: images/CIMG0098.JPG
#   Processing image 251/465: images/DSC00182.JPG
#   Processing image 252/465: images/IMG_3761.JPG
#     -> Skipping images/IMG_3761.JPG (preprocessing failed).
#   Processing image 253/465: images/IMG_4185.JPG
#   Processing image 254/465: images/IMG_4191.JPG
#   Processing image 255/465: images/CIMG0107.JPG
#   Processing image 256/465: images/CIMG0113.JPG
#   Processing image 257/465: images/CIMG0488.JPG
#   Processing image 258/465: images/IMG_3417.JPG
#   Processing image 259/465: images/IMG_3371.JPG
#   Processing image 260/465: images/IMG_20180726_154917733_BURST000_COVER_TOP.jpg
#   Processing image 261/465: images/IMG_3403.JPG
#     -> Skipping images/IMG_3403.JPG (preprocessing failed).
#   Processing image 262/465: images/IMG_3416.JPG
#   Processing image 263/465: images/IMG_3334(1).JPG
#   Processing image 264/465: images/IMG_3370.JPG
#   Processing image 265/465: images/CIMG0112.JPG
#   Processing image 266/465: images/IMG_4190.JPG
#   Processing image 267/465: images/IMG_4184.JPG
#   Processing image 268/465: images/DSC00183.JPG
#   Processing image 269/465: images/IMG_3748.JPG
#   Processing image 270/465: images/CIMG0099.JPG
#   Processing image 271/465: images/IMG_3569(1).JPG
#   Processing image 272/465: images/DSC00342.JPG
#   Processing image 273/465: images/CIMG0064(3).JPG
#   Processing image 274/465: images/CIMG0299.JPG
#   Processing image 275/465: images/CIMG0058.JPG
#   Processing image 276/465: images/CIMG0129~2.JPG
#   Processing image 277/465: images/CIMG0064.JPG
#   Processing image 278/465: images/CIMG0228~2.JPG
#   Processing image 279/465: images/CIMG0155(1).JPG
#   Processing image 280/465: images/IMG_4192.JPG
#   Processing image 281/465: images/IMG_4186.JPG
#   Processing image 282/465: images/CIMG0110.JPG
#   Processing image 283/465: images/CIMG0104.JPG
#   Processing image 284/465: images/IMG_3372.JPG
#   Processing image 285/465: images/IMG_3373.JPG
#   Processing image 286/465: images/CIMG0130~2.JPG
#   Processing image 287/465: images/IMG_4150.JPG
#   Processing image 288/465: images/CIMG0105.JPG
#   Processing image 289/465: images/CIMG0171(1).JPG
#   Processing image 290/465: images/IMG_4193.JPG
#   Processing image 291/465: images/CIMG0065.JPG
#   Processing image 292/465: images/CIMG0163(1).JPG
#   Processing image 293/465: images/CIMG0063(1).JPG
#   Processing image 294/465: images/CIMG0501.JPG
#   Processing image 295/465: images/IMG_20250705_121136381.jpg
#   Processing image 296/465: images/DSC00386.JPG
#   Processing image 297/465: images/CIMG0126(1).JPG
#   Processing image 298/465: images/CIMG0152(2).JPG
#   Processing image 299/465: images/CIMG0115.JPG
#   Processing image 300/465: images/CIMG0101.JPG
#   Processing image 301/465: images/IMG_4197.JPG
#   Processing image 302/465: images/CIMG0129.JPG
#   Processing image 303/465: images/CIMG0109~2.JPG
#   Processing image 304/465: images/CIMG0208~2.JPG
#   Processing image 305/465: images/CIMG0134(1).JPG
#   Processing image 306/465: images/CIMG0350~2.JPG
#   Processing image 307/465: images/IMG_3388.JPG
#   Processing image 308/465: images/IMG_3411.JPG
#   Processing image 309/465: images/IMG_3439.JPG
#     -> Skipping images/IMG_3439.JPG (preprocessing failed).
#   Processing image 310/465: images/IMG_3438.JPG
#   Processing image 311/465: images/IMG_3410.JPG
#   Processing image 312/465: images/IMG_3404.JPG
#   Processing image 313/465: images/IMG_20240822_085549698~3.jpg
#   Processing image 314/465: images/IMG_4196.JPG
#   Processing image 315/465: images/CIMG0128.JPG
#   Processing image 316/465: images/CIMG0100.JPG
#   Processing image 317/465: images/CIMG0672.JPG
#   Processing image 318/465: images/p4.jpg
#   Processing image 319/465: images/CIMG0074.JPG
#   Processing image 320/465: images/CIMG0060.JPG
#   Processing image 321/465: images/CIMG0110~2.JPG
#   Processing image 322/465: images/CIMG0064(2).JPG
#   Processing image 323/465: images/CIMG0538.JPG
#   Processing image 324/465: images/DSC00344.JPG
#   Processing image 325/465: images/CIMG0506.JPG
#   Processing image 326/465: images/CIMG0260.JPG
#   Processing image 327/465: images/CIMG0076.JPG
#   Processing image 328/465: images/CIMG0062.JPG
#   Processing image 329/465: images/p6.jpg
#   Processing image 330/465: images/CIMG0089.JPG
#   Processing image 331/465: images/CIMG0112~2.JPG
#   Processing image 332/465: images/IMG_20250708_120702744_HDR~2.jpg
#   Processing image 333/465: images/IMG_4194.JPG
#     -> Skipping images/IMG_4194.JPG (preprocessing failed).
#   Processing image 334/465: images/IMG_3412.JPG
#   Processing image 335/465: images/IMG_3406.JPG
#     -> Skipping images/IMG_3406.JPG (preprocessing failed).
#   Processing image 336/465: images/IMG_3348.JPG
#   Processing image 337/465: images/IMG_3361.JPG
#   Processing image 338/465: images/CIMG0080(1).JPG
#   Processing image 339/465: images/IMG_4142.JPG
#   Processing image 340/465: images/IMG_4195.JPG
#   Processing image 341/465: images/CIMG0117.JPG
#     -> Skipping images/CIMG0117.JPG (preprocessing failed).
#   Processing image 342/465: images/DSC00186.JPG
#   Processing image 343/465: images/p7.jpg
#   Processing image 344/465: images/CIMG0063.JPG
#   Processing image 345/465: images/CIMG0077.JPG
#   Processing image 346/465: images/CIMG0092(1).JPG
#   Processing image 347/465: images/CIMG0261.JPG
#   Processing image 348/465: images/DSC00320.JPG
#   Processing image 349/465: images/CIMG0206.JPG
#   Processing image 350/465: images/RIMG0919.JPG
#   Processing image 351/465: images/CIMG0014(1).JPG
#   Processing image 352/465: images/CIMG0979.jpg
#   Processing image 353/465: images/CIMG0158.JPG
#   Processing image 354/465: images/CIMG0602.JPG
#   Processing image 355/465: images/CIMG0229~2.JPG
#   Processing image 356/465: images/IMG_4131.JPG
#   Processing image 357/465: images/IMG_3676.JPG
#     -> Skipping images/IMG_3676.JPG (preprocessing failed).
#   Processing image 358/465: images/DSC00095.JPG
#   Processing image 359/465: images/CIMG0118(1).JPG
#   Processing image 360/465: images/CIMG0334~2.JPG
#   Processing image 361/465: images/CIMG0428.JPG
#   Processing image 362/465: images/CIMG0400.JPG
#   Processing image 363/465: images/CIMG0372.JPG
#   Processing image 364/465: images/IMG_20250705_125343397.jpg
#   Processing image 365/465: images/CIMG0757(1).JPG
#   Processing image 366/465: images/100820081695.jpg
#   Processing image 367/465: images/100820081694.jpg
#   Processing image 368/465: images/CIMG0367.JPG
#   Processing image 369/465: images/CIMG0401.JPG
#   Processing image 370/465: images/IMG_20250710_100837.jpg
#   Processing image 371/465: images/CIMG0171.JPG
#   Processing image 372/465: images/CIMG0130(1).JPG
#   Processing image 373/465: images/IMG_3844.JPG
#   Processing image 374/465: images/CIMG0159.JPG
#   Processing image 375/465: images/CIMG0005.JPG
#   Processing image 376/465: images/CIMG0011.JPG
#   Processing image 377/465: images/CIMG0131~2.JPG
#   Processing image 378/465: images/IMG_20250705_170544521.jpg
#   Processing image 379/465: images/CIMG0230~2.JPG
#     -> Skipping images/CIMG0230~2.JPG (preprocessing failed).
#   Processing image 380/465: images/CIMG0239.JPG
#   Processing image 381/465: images/CIMG0577.JPG
#   Processing image 382/465: images/CIMG0096~2.JPG
#   Processing image 383/465: images/CIMG0188(1).JPG
#   Processing image 384/465: images/CIMG0232~2.JPG
#     -> Skipping images/CIMG0232~2.JPG (preprocessing failed).
#   Processing image 385/465: images/Rimg0149s.jpg
#     -> Skipping images/Rimg0149s.jpg (preprocessing failed).
#   Processing image 386/465: images/CIMG0133~2.JPG
#   Processing image 387/465: images/CIMG0579(2).JPG
#   Processing image 388/465: images/IMG_3701.JPG
#     -> Skipping images/IMG_3701.JPG (preprocessing failed).
#   Processing image 389/465: images/IMG_3332(1).JPG
#   Processing image 390/465: images/CIMG0167.JPG
#   Processing image 391/465: images/CIMG0601.JPG
#   Processing image 392/465: images/CIMG0198.JPG
#   Processing image 393/465: images/DSC00096.JPG
#   Processing image 394/465: images/p24.jpg
#   Processing image 395/465: images/CIMG0371.JPG
#   Processing image 396/465: images/IMG_3477.JPG
#     -> Skipping images/IMG_3477.JPG (preprocessing failed).
#   Processing image 397/465: images/IMG_3338.JPG
#   Processing image 398/465: images/p19.jpg
#   Processing image 399/465: images/CIMG0402.JPG
#   Processing image 400/465: images/CIMG0364.JPG
#   Processing image 401/465: images/p25.jpg
#   Processing image 402/465: images/IMG_3674.JPG
#     -> Skipping images/IMG_3674.JPG (preprocessing failed).
#   Processing image 403/465: images/CIMG0199.JPG
#   Processing image 404/465: images/IMG_20180724_170036332.jpg
#   Processing image 405/465: images/IMG_3700.JPG
#     -> Skipping images/IMG_3700.JPG (preprocessing failed).
#   Processing image 406/465: images/CIMG0426~2.JPG
#   Processing image 407/465: images/IMG_20250524_140427028.jpg
#   Processing image 408/465: images/CIMG0209(1).JPG
#   Processing image 409/465: images/CIMG0006.JPG
#   Processing image 410/465: images/DSC_0359.JPG
#   Processing image 411/465: images/DSC00322.JPG
#   Processing image 412/465: images/CIMG0210.JPG
#     -> Skipping images/CIMG0210.JPG (preprocessing failed).
#   Processing image 413/465: images/RIMG0066.JPG
#   Processing image 414/465: images/CIMG0200.JPG
#   Processing image 415/465: images/CIMG0572.JPG
#   Processing image 416/465: images/CIMG0228.JPG
#   Processing image 417/465: images/RIMG0076.JPG
#   Processing image 418/465: images/29032008701.jpg
#   Processing image 419/465: images/CIMG0599.JPG
#   Processing image 420/465: images/CIMG0002.JPG
#   Processing image 421/465: images/CIMG0297~2.JPG
#   Processing image 422/465: images/IMG_3410(1).JPG
#   Processing image 423/465: images/CIMG0980.jpg
#   Processing image 424/465: images/CIMG0604.JPG
#   Processing image 425/465: images/CIMG0162.JPG
#   Processing image 426/465: images/DSC02848.JPG
#   Processing image 427/465: images/CIMG0113~2.JPG
#   Processing image 428/465: images/CIMG0412.JPG
#   Processing image 429/465: images/100820081693.jpg
#   Processing image 430/465: images/IMG_20180724_170112733.jpg
#   Processing image 431/465: images/CIMG0137~2.JPG
#   Processing image 432/465: images/100820081692.jpg
#   Processing image 433/465: images/IMG_20180724_170028451.jpg
#   Processing image 434/465: images/CIMG0188.JPG
#   Processing image 435/465: images/CIMG0605.JPG
#   Processing image 436/465: images/CIMG0163.JPG
#   Processing image 437/465: images/IMG_3369(1).JPG
#   Processing image 438/465: images/CIMG0017.JPG
#   Processing image 439/465: images/DSC_0360.JPG
#   Processing image 440/465: images/CIMG0573.JPG
#   Processing image 441/465: images/CIMG0217.JPG
#   Processing image 442/465: images/DSC00319.JPG
#   Processing image 443/465: images/RIMG0075.JPG
#   Processing image 444/465: images/CIMG0079(1).JPG
#   Processing image 445/465: images/CIMG0015.JPG
#   Processing image 446/465: images/CIMG0067(1).JPG
#   Processing image 447/465: images/CIMG0029.JPG
#   Processing image 448/465: images/CIMG0108~2.JPG
#   Processing image 449/465: images/CIMG0209~2.JPG
#   Processing image 450/465: images/IMG_20211223_163150170_HDR.jpg
#   Processing image 451/465: images/CIMG0149.JPG
#   Processing image 452/465: images/IMG_20180726_154940261_BURST000_COVER_TOP.jpg
#   Processing image 453/465: images/CIMG0170~2.JPG
#   Processing image 454/465: images/IMG_20250524_143429630.jpg
#   Processing image 455/465: images/CIMG0090~2.JPG
#   Processing image 456/465: images/CIMG0111~2.JPG
#   Processing image 457/465: images/IMG_20250627_104711559_HDR.jpg
#   Processing image 458/465: images/CIMG0120(1).JPG
#     -> Skipping images/CIMG0120(1).JPG (preprocessing failed).
#   Processing image 459/465: images/IMG_3699.JPG
#     -> Skipping images/IMG_3699.JPG (preprocessing failed).
#   Processing image 460/465: images/141120142185.jpg
#   Processing image 461/465: images/CIMG0160.JPG
#   Processing image 462/465: images/IMG_3706.JPG
#   Processing image 463/465: images/CIMG0014.JPG
#   Processing image 464/465: images/CIMG0089~2.JPG
#   Processing image 465/465: images/IMG_4158(1).JPG
#
# Feature extraction complete in 337.86s
# Extracted 1066 features from 27584 total cells.
# Scaling features...
# Finding optimal k using Silhouette Score...
#   Testing k=2...
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
#     (Calculating score on a sample of 10k points)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#   -> Silhouette Score: 0.1044
#   Testing k=3...
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
#     (Calculating score on a sample of 10k points)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#   -> Silhouette Score: 0.0913
#   Testing k=4...
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
#     (Calculating score on a sample of 10k points)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#   -> Silhouette Score: 0.0671
#   Testing k=5...
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
#     (Calculating score on a sample of 10k points)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#   -> Silhouette Score: 0.0631
#   Testing k=6...
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
#     (Calculating score on a sample of 10k points)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#   -> Silhouette Score: 0.0642
#   Testing k=7...
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
#     (Calculating score on a sample of 10k points)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
#   -> Silhouette Score: 0.0638
#
# Best k found: 2 (Score: 0.1044)
# Training final model with k=2...
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: divide by zero encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/extmath.py:203: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: divide by zero encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: overflow encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/cluster/_kmeans.py:237: RuntimeWarning: invalid value encountered in matmul
#   current_pot = closest_dist_sq @ sample_weight
# Saving model to wildlife_cluster_model.pkl...
#
# --- Training Complete ---
# Model (scaler + kmeans) saved successfully to 'wildlife_cluster_model.pkl'.
# You can now run the prediction script.

# %%
# --- Configuration ---
MODEL_PATH = "wildlife_cluster_model.pkl"
INPUT_FOLDER = "images" # Folder to read images from
OUTPUT_FOLDER = "cluster_visualizations_3" # Folder to save visualizations to

# --- Constants (MUST be identical to training script) ---
GRID_W = 100  # 800 / 8
GRID_H = 75   # 600 / 8
TARGET_ASPECT_RATIO = 4.0 / 3.0
LBP_RADIUS = 1
LBP_POINTS = 8 * LBP_RADIUS
# Ensure LBP config matches our manual CLBP function
assert LBP_RADIUS == 1 and LBP_POINTS == 8, "CLBP implementation is specific to R=1, P=8"


# --- Processing Functions (Must be identical to training script) ---
def process_image_for_prediction(path: str):
    """
    Loads an image for prediction.
    Returns:
        - display_img (np.ndarray): 800x600 BGR image for drawing on.
        - processing_img (np.ndarray): 800x600 HSV image for feature extraction.
        - or (None, None) if processing fails.
    """
    img = cv2.imread(path)
    if img is None:
        print(f"Warning: Could not read image at {path}")
        return None, None
    
    h, w, _ = img.shape
    current_aspect_ratio = w / h
    
    # a. Crop to 4:3 aspect ratio
    if not np.isclose(current_aspect_ratio, TARGET_ASPECT_RATIO):
        if current_aspect_ratio > TARGET_ASPECT_RATIO:
            new_w = int(TARGET_ASPECT_RATIO * h)
            x_start = (w - new_w) // 2
            img = img[:, x_start:x_start + new_w]
        else:
            new_h = int(w / TARGET_ASPECT_RATIO)
            y_start = (h - new_h) // 2
            img = img[y_start:y_start + new_h, :]
    
    # --- START OF MODIFIED SECTION ---
    # This logic is now identical to the training script
    
    # b. Scale down if larger than 800x600
    h, w, _ = img.shape
    if w > 800 or h > 600:
        img = cv2.resize(img, (800, 600), interpolation=cv2.INTER_AREA)

    # c. Do not scale up if smaller than 800x600 (discard)
    h, w, _ = img.shape
    if w < 800 or h < 600:
        print(f" -> Skipping {path} (Image is < 800x600, same as training)")
        return None, None
    
    # d. Create both BGR and HSV versions
    display_img = img.copy()
    processing_img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV) # Fixed typo
    
    # --- END OF MODIFIED SECTION ---
    
    return display_img, processing_img

# --- CLBP Helper Function (Identical to training) ---
def compute_clbp_components(image: np.ndarray) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """
    Calculates the Completed LBP (CLBP) components: S, M, and C.
    This implementation is for R=1, P=8.
    """
    img_float = image.astype(np.float64)
    padded = np.pad(img_float, (1, 1), 'edge')
    
    center = padded[1:-1, 1:-1]
    neighbors = [
        padded[ :-2,  :-2], padded[ :-2, 1:-1], padded[ :-2, 2:  ],
        padded[1:-1, 2:  ], padded[2:  , 2:  ], padded[2:  , 1:-1],
        padded[2:  ,  :-2], padded[1:-1,  :-2]
    ]
    
    diffs = [n - center for n in neighbors]
    mags = [np.abs(d) for d in diffs]
    
    clbp_s = np.zeros_like(center, dtype=np.int64) 
    for i in range(LBP_POINTS):
        clbp_s += ((diffs[i] >= 0) * (2**i))
        
    mean_mag = np.mean([m.ravel() for m in mags])
    
    clbp_m = np.zeros_like(center, dtype=np.int64)
    for i in range(LBP_POINTS):
        clbp_m += ((mags[i] >= mean_mag) * (2**i))

    mean_center = np.mean(center)
    clbp_c = (center >= mean_center).astype(np.uint8)
    
    return clbp_s.astype(np.uint8), clbp_m.astype(np.uint8), clbp_c


# --- Feature Extraction (MODIFIED to include HOG) ---
def extract_features_from_cell(cell: np.ndarray) -> np.ndarray:
    """
    Extracts features from a single 100x75 3-channel HSV grid cell.
    (Identical to training script)
    """
    features = []
    h, s, v = cv2.split(cell)
    
    # 1. Color Features
    features.append(np.mean(h))
    features.append(np.std(h))
    features.append(np.mean(s))
    features.append(np.std(s))
    
    # 2. Statistical Features (from V)
    features.append(np.mean(v))
    features.append(np.std(v))
    
    v_uint8 = v.astype(np.uint8)

    # 3. Completed LBP (CLBP) Histograms (from V channel)
    clbp_s, clbp_m, clbp_c = compute_clbp_components(v_uint8)
    
    hist_s, _ = np.histogram(clbp_s.ravel(), bins=np.arange(0, 257), density=True)
    features.extend(hist_s)
    
    hist_m, _ = np.histogram(clbp_m.ravel(), bins=np.arange(0, 257), density=True)
    features.extend(hist_m)
    
    hist_c, _ = np.histogram(clbp_c.ravel(), bins=np.arange(0, 3), density=True)
    features.extend(hist_c)
    
    # 4. GLCM Texture Features (from V)
    glcm = graycomatrix(v_uint8, distances=[1], 
                        angles=[0, np.pi/4, np.pi/2, 3*np.pi/4],
                        levels=256, symmetric=True, normed=True)
    
    features.extend([
        np.mean(graycoprops(glcm, 'contrast')),
        np.mean(graycoprops(glcm, 'dissimilarity')),
        np.mean(graycoprops(glcm, 'homogeneity')),
        np.mean(graycoprops(glcm, 'energy')),
        np.mean(graycoprops(glcm, 'correlation'))
    ])
    
    # --- 5. HOG Features (from V channel) ---
    # This section is added to match the training script
    hog_features = hog(v_uint8, 
                       orientations=9, 
                       pixels_per_cell=(16, 16),
                       cells_per_block=(2, 2), 
                       block_norm='L2-Hys', 
                       feature_vector=True)
    features.extend(hog_features)

    # --- 6. Canny Edge (from V) ---
    edges = cv2.Canny(v_uint8, 50, 150)
    features.append(np.sum(edges > 0) / v.size)
    
    return np.array(features)

def extract_features_from_image(img: np.ndarray) -> np.ndarray:
    """
    Extracts features from all 64 cells in a single HSV image.
    """
    features_list = []
    for y in range(0, img.shape[0], GRID_H):
        for x in range(0, img.shape[1], GRID_W):
            cell = img[y:y+GRID_H, x:x+GRID_W]
            features_list.append(extract_features_from_cell(cell))
    return np.vstack(features_list)

# --- Main Visualization Logic (Unchanged) ---
if __name__ == "__main__":
    
    # 1. Check if model and image folder exist
    if not os.path.exists(MODEL_PATH):
        print(f"Error: Model file not found at '{MODEL_PATH}'")
        print("Please run the training script first.")
        exit()
        
    if not os.path.exists(INPUT_FOLDER):
        print(f"Error: Input folder not found at '{INPUT_FOLDER}'")
        exit()

    os.makedirs(OUTPUT_FOLDER, exist_ok=True)
    print(f"Saving visualizations to '{OUTPUT_FOLDER}'")

    print("Loading models...")
    # 2. Load the trained scaler and kmeans model
    models = joblib.load(MODEL_PATH)
    scaler = models['scaler']
    kmeans = models['kmeans']
    k = kmeans.n_clusters
    print(f"Successfully loaded model with k={k} clusters.")

    # 3. Generate stable, random colors for each cluster
    np.random.seed(42) 
    cluster_colors = np.random.randint(0, 256, (k, 3), dtype=np.uint8)
    cluster_colors_list = [tuple(map(int, color)) for color in cluster_colors]
    
    # 4. Find all images in the input folder
    image_paths = [
        os.path.join(INPUT_FOLDER, f) for f in os.listdir(INPUT_FOLDER) 
        if f.lower().endswith(('png', 'jpg', 'jpeg'))
    ]
    
    if not image_paths:
        print(f"Error: No images found in '{INPUT_FOLDER}'.")
        exit()
        
    print(f"Found {len(image_paths)} images to process...")

    # 5. Loop over each image path and process it
    for image_path in image_paths:
        print(f"Processing: {image_path}")
        
        # a. Process the test image
        # This will now return (None, None) for small images
        display_image, processing_image = process_image_for_prediction(image_path)
        
        # This 'if' statement now correctly skips the bad images
        if display_image is None:
            continue

        # b. Extract features and predict clusters
        features = extract_features_from_image(processing_image)
        scaled_features = scaler.transform(features)
        labels = kmeans.predict(scaled_features) 

        # c. Create the visualization
        overlay = display_image.copy()
        output_image = display_image.copy()
        
        i = 0 
        for y in range(0, display_image.shape[0], GRID_H):
            for x in range(0, display_image.shape[1], GRID_W):
                cluster_id = labels[i]
                color = cluster_colors_list[cluster_id]
                
                cv2.rectangle(overlay, (x, y), (x + GRID_W, y + GRID_H), color, -1)
                cv2.rectangle(output_image, (x, y), (x + GRID_W, y + GRID_H), (0, 0, 0), 1)
                
                text = str(cluster_id)
                text_pos = (x + 10, y + 40)
                cv2.putText(output_image, text, text_pos, 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 0), 3, cv2.LINE_AA)
                cv2.putText(output_image, text, text_pos, 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
                
                i += 1

        # d. Blend the overlay with the output image
        alpha = 0.6  
        cv2.addWeighted(overlay, alpha, output_image, 1 - alpha, 0, output_image)

        # e. Save the final image
        base_filename = os.path.basename(image_path)
        name, ext = os.path.splitext(base_filename)
        output_path = os.path.join(OUTPUT_FOLDER, f"{name}_clustered{ext}")
        
        cv2.imwrite(output_path, output_image)
    
    print("\n--- Done ---")
    print(f"All visualizations saved to: {OUTPUT_FOLDER}")
# Out:
# Saving visualizations to 'cluster_visualizations_3'
# Loading models...
# Successfully loaded model with k=2 clusters.
# Found 465 images to process...
# Processing: images/RIMG0051.JPG
# Processing: images/CIMG0496(1).JPG
# Processing: images/CIMG0569.JPG
# Processing: images/CIMG0233.JPG
#  -> Skipping images/CIMG0233.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0555.JPG
# Processing: images/RIMG0079.JPG
# Processing: images/CIMG0757.JPG
# Processing: images/CIMG0067(2).JPG
# Processing: images/IMG_20180726_154742802.jpg
# Processing: images/CIMG0958.JPG
# Processing: images/CIMG0179.JPG
# Processing: images/IMG_20250709_164054571_HDR~2.jpg
# Processing: images/CIMG0162(1).JPG
# Processing: images/IMG_3858.JPG
#  -> Skipping images/IMG_3858.JPG (Image is < 800x600, same as training)
# Processing: images/DSC02847.JPG
# Processing: images/CIMG0186.JPG
# Processing: images/CIMG0192.JPG
# Processing: images/p12.jpg
# Processing: images/IMG_3332.JPG
#  -> Skipping images/IMG_3332.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0139~2.JPG
# Processing: images/CIMG0434.JPG
# Processing: images/CIMG0408.JPG
# Processing: images/CIMG0120(2).JPG
# Processing: images/RIMG0124.JPG
# Processing: images/CIMG0129(1).JPG
# Processing: images/RIMG1945.JPG
# Processing: images/CIMG0150.JPG
# Processing: images/CIMG0144.JPG
# Processing: images/CIMG0178.JPG
# Processing: images/CIMG0318~2.JPG
# Processing: images/IMG_20250705_125546309.jpg
# Processing: images/CIMG0030.JPG
# Processing: images/CIMG0018.JPG
# Processing: images/CIMG0108~2(1).JPG
# Processing: images/CIMG0158(1).JPG
# Processing: images/CIMG0232.JPG
# Processing: images/RIMG0050.JPG
# Processing: images/CIMG0218.JPG
#  -> Skipping images/CIMG0218.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_20250709_163052484_HDR~2.jpg
# Processing: images/CIMG0569(1).JPG
# Processing: images/CIMG0595.JPG
# Processing: images/CIMG0608.JPG
# Processing: images/CIMG0506(1).JPG
# Processing: images/CIMG1270.JPG
# Processing: images/IMG_4194(1).JPG
# Processing: images/CIMG0152.JPG
# Processing: images/IMG_20250709_164031681_HDR~2.jpg
# Processing: images/CIMG0191.JPG
# Processing: images/CIMG0378.JPG
# Processing: images/CIMG0422.JPG
# Processing: images/CIMG0344.JPG
# Processing: images/CIMG0083(1).JPG
# Processing: images/29032008693.jpg
# Processing: images/p10.jpg
# Processing: images/IMG_1724.JPG
# Processing: images/CIMG0190.JPG
# Processing: images/CIMG0147.JPG
# Processing: images/IMG_3682.JPG
# Processing: images/CIMG0153.JPG
# Processing: images/CIMG0980(1).JPG
# Processing: images/CIMG0594.JPG
# Processing: images/CIMG0580.JPG
# Processing: images/CIMG0225.JPG
# Processing: images/CIMG0210(1).JPG
# Processing: images/RIMG0047.JPG
# Processing: images/IMG_20250705_142522.jpg
# Processing: images/CIMG0221.JPG
# Processing: images/CIMG0342~2.JPG
# Processing: images/CIMG0209.JPG
#  -> Skipping images/CIMG0209.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0584.JPG
# Processing: images/CIMG0228(1).JPG
#  -> Skipping images/CIMG0228(1).JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0579(1).JPG
# Processing: images/IMG_3686.JPG
#  -> Skipping images/IMG_3686.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0143.JPG
# Processing: images/CIMG0126~2.JPG
# Processing: images/CIMG0180.JPG
# Processing: images/CIMG0427.JPG
# Processing: images/CIMG0382~2.JPG
# Processing: images/IMG_20221207_075613681.jpg
# Processing: images/IMG_3334.JPG
#  -> Skipping images/IMG_3334.JPG (Image is < 800x600, same as training)
# Processing: images/29032008696.jpg
# Processing: images/CIMG0426.JPG
# Processing: images/CIMG0432.JPG
# Processing: images/CIMG0181.JPG
# Processing: images/CIMG0142.JPG
# Processing: images/IMG_3687.JPG
# Processing: images/RIMG0081.JPG
# Processing: images/CIMG0585.JPG
# Processing: images/CIMG0208.JPG
# Processing: images/CIMG0234.JPG
# Processing: images/CIMG0546.JPG
# Processing: images/CIMG0236.JPG
# Processing: images/CIMG0578.JPG
# Processing: images/CIMG0593.JPG
# Processing: images/CIMG0034.JPG
# Processing: images/CIMG0975.JPG
# Processing: images/CIMG0140.JPG
# Processing: images/CIMG0154.JPG
# Processing: images/CIMG0168.JPG
# Processing: images/CIMG0100~2.JPG
# Processing: images/CIMG0118(2).JPG
# Processing: images/CIMG0197.JPG
# Processing: images/CIMG0342.JPG
# Processing: images/p17.jpg
# Processing: images/CIMG0757(2).JPG
# Processing: images/CIMG0394.JPG
# Processing: images/IMG_3337.JPG
#  -> Skipping images/IMG_3337.JPG (Image is < 800x600, same as training)
# Processing: images/p16.jpg
# Processing: images/CIMG0225~2.JPG
# Processing: images/CIMG0431.JPG
# Processing: images/29032008695.jpg
# Processing: images/CIMG0196.JPG
# Processing: images/IMG_3653.JPG
#  -> Skipping images/IMG_3653.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0155.JPG
# Processing: images/CIMG0141.JPG
# Processing: images/CIMG0035.JPG
# Processing: images/CIMG0135(1).JPG
# Processing: images/CIMG0579.JPG
# Processing: images/CIMG0119~2.JPG
# Processing: images/26102010062.jpg
# Processing: images/CIMG0428(1).JPG
# Processing: images/CIMG0126.JPG
# Processing: images/IMG_4198.JPG
# Processing: images/IMG_4173.JPG
# Processing: images/CIMG0107~2.JPG
# Processing: images/CIMG0442.JPG
# Processing: images/IMG_3393.JPG
# Processing: images/IMG_3387.JPG
# Processing: images/CIMG0330.JPG
# Processing: images/IMG_3378.JPG
# Processing: images/CIMG0495.JPG
# Processing: images/CIMG0494.JPG
# Processing: images/IMG-20140317-WA0001.jpg
#  -> Skipping images/IMG-20140317-WA0001.jpg (Image is < 800x600, same as training)
# Processing: images/IMG_3386.JPG
# Processing: images/CIMG0319.JPG
# Processing: images/IMG_4172.JPG
# Processing: images/CIMG0127.JPG
# Processing: images/CIMG0084.JPG
# Processing: images/CIMG0047.JPG
# Processing: images/CIMG0537.JPG
# Processing: images/CIMG0253.JPG
# Processing: images/CIMG0001~2.JPG
# Processing: images/CIMG0079.JPG
# Processing: images/p9.jpg
# Processing: images/CIMG0152(1).JPG
# Processing: images/CIMG0086.JPG
# Processing: images/CIMG0092.JPG
# Processing: images/CIMG0119.JPG
# Processing: images/CIMG0123(1).JPG
# Processing: images/CIMG0125.JPG
# Processing: images/IMG_4164.JPG
# Processing: images/IMG_3637.JPG
# Processing: images/IMG_4158.JPG
# Processing: images/CIMG0134(2).JPG
# Processing: images/CIMG0333.JPG
# Processing: images/CIMG0079~2.JPG
# Processing: images/CIMG0140(1).JPG
# Processing: images/IMG_3409.JPG
#  -> Skipping images/IMG_3409.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0496.JPG
# Processing: images/IMG_3347.JPG
# Processing: images/CIMG0115(1).JPG
# Processing: images/IMG_20250705_121136381~2.jpg
# Processing: images/CIMG0079~3.JPG
# Processing: images/CIMG0068(1).JPG
# Processing: images/IMG_3385.JPG
# Processing: images/IMG_20250627_105023208.jpg
# Processing: images/IMG_4165.JPG
# Processing: images/IMG_4171.JPG
# Processing: images/CIMG0642.JPG
# Processing: images/CIMG0124.JPG
# Processing: images/CIMG0130.JPG
# Processing: images/IMG_3839.JPG
#  -> Skipping images/IMG_3839.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0118.JPG
# Processing: images/p8.jpg
# Processing: images/IMG_20180726_154804552.jpg
# Processing: images/CIMG0078.JPG
# Processing: images/CIMG0138~2.JPG
# Processing: images/CIMG0064(1).JPG
# Processing: images/CIMG0242.JPG
# Processing: images/CIMG0256.JPG
# Processing: images/IMG_3550.JPG
# Processing: images/CIMG0054.JPG
# Processing: images/CIMG0083.JPG
# Processing: images/CIMG0097.JPG
# Processing: images/CIMG0134.JPG
# Processing: images/CIMG0120.JPG
# Processing: images/CIMG0108.JPG
# Processing: images/CIMG0914(1).JPG
# Processing: images/IMG_4175.JPG
# Processing: images/IMG_2510.JPG
# Processing: images/CIMG0131~2(1).JPG
# Processing: images/IMG_3395.JPG
# Processing: images/CIMG0099~2.JPG
# Processing: images/CIMG0493.JPG
# Processing: images/CIMG0064~2.JPG
# Processing: images/CIMG0487.JPG
# Processing: images/CIMG0021~2.JPG
# Processing: images/IMG_3418.JPG
# Processing: images/IMG_3419.JPG
#  -> Skipping images/IMG_3419.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0486.JPG
# Processing: images/IMG_3394.JPG
# Processing: images/CIMG0118~2.JPG
# Processing: images/IMG_4174.JPG
# Processing: images/CIMG0121.JPG
# Processing: images/CIMG0171(2).JPG
# Processing: images/CIMG0135.JPG
# Processing: images/CIMG0914.jpg
# Processing: images/CIMG0096.JPG
# Processing: images/IMG_3747.JPG
#  -> Skipping images/IMG_3747.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0144~3.JPG
#  -> Skipping images/CIMG0144~3.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0381~2.JPG
# Processing: images/IMG_20180726_154949063_BURST001.jpg
# Processing: images/CIMG0117(1).JPG
# Processing: images/CIMG0160~2.JPG
# Processing: images/CIMG0531.JPG
# Processing: images/CIMG0224~2.JPG
# Processing: images/CIMG0257.JPG
# Processing: images/Photo0044.jpg
# Processing: images/CIMG0127~2.JPG
# Processing: images/CIMG0080.JPG
# Processing: images/CIMG0123.JPG
# Processing: images/CIMG0137.JPG
# Processing: images/CIMG0365(1).JPG
# Processing: images/IMG_4176.JPG
# Processing: images/IMG_20180401_143225122_HDR.jpg
# Processing: images/CIMG0484.JPG
# Processing: images/CIMG0490.JPG
# Processing: images/IMG_3369.JPG
#  -> Skipping images/IMG_3369.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3368.JPG
# Processing: images/CIMG0491.JPG
# Processing: images/CIMG0485.JPG
# Processing: images/CIMG0320.JPG
# Processing: images/CIMG0081.JPG
# Processing: images/CIMG0095.JPG
# Processing: images/IMG_4182(1).JPG
# Processing: images/IMG_3403(1).JPG
# Processing: images/CIMG0056.JPG
# Processing: images/CIMG0103~2.JPG
# Processing: images/CIMG0146~2.JPG
# Processing: images/RIMG1328.JPG
# Processing: images/CIMG0268.JPG
# Processing: images/CIMG0254.JPG
# Processing: images/CIMG1147.JPG
# Processing: images/DSC00343.JPG
# Processing: images/CIMG0271.JPG
# Processing: images/CIMG0265.JPG
# Processing: images/CIMG0012~2.JPG
# Processing: images/CIMG0073.JPG
# Processing: images/CIMG0067.JPG
# Processing: images/CIMG0098.JPG
# Processing: images/DSC00182.JPG
# Processing: images/IMG_3761.JPG
#  -> Skipping images/IMG_3761.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_4185.JPG
# Processing: images/IMG_4191.JPG
# Processing: images/CIMG0107.JPG
# Processing: images/CIMG0113.JPG
# Processing: images/CIMG0488.JPG
# Processing: images/IMG_3417.JPG
# Processing: images/IMG_3371.JPG
# Processing: images/IMG_20180726_154917733_BURST000_COVER_TOP.jpg
# Processing: images/IMG_3403.JPG
#  -> Skipping images/IMG_3403.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3416.JPG
# Processing: images/IMG_3334(1).JPG
# Processing: images/IMG_3370.JPG
# Processing: images/CIMG0112.JPG
# Processing: images/IMG_4190.JPG
# Processing: images/IMG_4184.JPG
# Processing: images/DSC00183.JPG
# Processing: images/IMG_3748.JPG
# Processing: images/CIMG0099.JPG
# Processing: images/IMG_3569(1).JPG
# Processing: images/DSC00342.JPG
# Processing: images/CIMG0064(3).JPG
# Processing: images/CIMG0299.JPG
# Processing: images/CIMG0058.JPG
# Processing: images/CIMG0129~2.JPG
# Processing: images/CIMG0064.JPG
# Processing: images/CIMG0228~2.JPG
# Processing: images/CIMG0155(1).JPG
# Processing: images/IMG_4192.JPG
# Processing: images/IMG_4186.JPG
# Processing: images/CIMG0110.JPG
# Processing: images/CIMG0104.JPG
# Processing: images/IMG_3372.JPG
# Processing: images/IMG_3373.JPG
# Processing: images/CIMG0130~2.JPG
# Processing: images/IMG_4150.JPG
# Processing: images/CIMG0105.JPG
# Processing: images/CIMG0171(1).JPG
# Processing: images/IMG_4193.JPG
# Processing: images/CIMG0065.JPG
# Processing: images/CIMG0163(1).JPG
# Processing: images/CIMG0063(1).JPG
# Processing: images/CIMG0501.JPG
# Processing: images/IMG_20250705_121136381.jpg
# Processing: images/DSC00386.JPG
# Processing: images/CIMG0126(1).JPG
# Processing: images/CIMG0152(2).JPG
# Processing: images/CIMG0115.JPG
# Processing: images/CIMG0101.JPG
# Processing: images/IMG_4197.JPG
# Processing: images/CIMG0129.JPG
# Processing: images/CIMG0109~2.JPG
# Processing: images/CIMG0208~2.JPG
# Processing: images/CIMG0134(1).JPG
# Processing: images/CIMG0350~2.JPG
# Processing: images/IMG_3388.JPG
# Processing: images/IMG_3411.JPG
# Processing: images/IMG_3439.JPG
#  -> Skipping images/IMG_3439.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3438.JPG
# Processing: images/IMG_3410.JPG
# Processing: images/IMG_3404.JPG
# Processing: images/IMG_20240822_085549698~3.jpg
# Processing: images/IMG_4196.JPG
# Processing: images/CIMG0128.JPG
# Processing: images/CIMG0100.JPG
# Processing: images/CIMG0672.JPG
# Processing: images/p4.jpg
# Processing: images/CIMG0074.JPG
# Processing: images/CIMG0060.JPG
# Processing: images/CIMG0110~2.JPG
# Processing: images/CIMG0064(2).JPG
# Processing: images/CIMG0538.JPG
# Processing: images/DSC00344.JPG
# Processing: images/CIMG0506.JPG
# Processing: images/CIMG0260.JPG
# Processing: images/CIMG0076.JPG
# Processing: images/CIMG0062.JPG
# Processing: images/p6.jpg
# Processing: images/CIMG0089.JPG
# Processing: images/CIMG0112~2.JPG
# Processing: images/IMG_20250708_120702744_HDR~2.jpg
# Processing: images/IMG_4194.JPG
#  -> Skipping images/IMG_4194.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3412.JPG
# Processing: images/IMG_3406.JPG
#  -> Skipping images/IMG_3406.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3348.JPG
# Processing: images/IMG_3361.JPG
# Processing: images/CIMG0080(1).JPG
# Processing: images/IMG_4142.JPG
# Processing: images/IMG_4195.JPG
# Processing: images/CIMG0117.JPG
#  -> Skipping images/CIMG0117.JPG (Image is < 800x600, same as training)
# Processing: images/DSC00186.JPG
# Processing: images/p7.jpg
# Processing: images/CIMG0063.JPG
# Processing: images/CIMG0077.JPG
# Processing: images/CIMG0092(1).JPG
# Processing: images/CIMG0261.JPG
# Processing: images/DSC00320.JPG
# Processing: images/CIMG0206.JPG
# Processing: images/RIMG0919.JPG
# Processing: images/CIMG0014(1).JPG
# Processing: images/CIMG0979.jpg
# Processing: images/CIMG0158.JPG
# Processing: images/CIMG0602.JPG
# Processing: images/CIMG0229~2.JPG
# Processing: images/IMG_4131.JPG
# Processing: images/IMG_3676.JPG
#  -> Skipping images/IMG_3676.JPG (Image is < 800x600, same as training)
# Processing: images/DSC00095.JPG
# Processing: images/CIMG0118(1).JPG
# Processing: images/CIMG0334~2.JPG
# Processing: images/CIMG0428.JPG
# Processing: images/CIMG0400.JPG
# Processing: images/CIMG0372.JPG
# Processing: images/IMG_20250705_125343397.jpg
# Processing: images/CIMG0757(1).JPG
# Processing: images/100820081695.jpg
# Processing: images/100820081694.jpg
# Processing: images/CIMG0367.JPG
# Processing: images/CIMG0401.JPG
# Processing: images/IMG_20250710_100837.jpg
# Processing: images/CIMG0171.JPG
# Processing: images/CIMG0130(1).JPG
# Processing: images/IMG_3844.JPG
# Processing: images/CIMG0159.JPG
# Processing: images/CIMG0005.JPG
# Processing: images/CIMG0011.JPG
# Processing: images/CIMG0131~2.JPG
# Processing: images/IMG_20250705_170544521.jpg
# Processing: images/CIMG0230~2.JPG
#  -> Skipping images/CIMG0230~2.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0239.JPG
# Processing: images/CIMG0577.JPG
# Processing: images/CIMG0096~2.JPG
# Processing: images/CIMG0188(1).JPG
# Processing: images/CIMG0232~2.JPG
#  -> Skipping images/CIMG0232~2.JPG (Image is < 800x600, same as training)
# Processing: images/Rimg0149s.jpg
#  -> Skipping images/Rimg0149s.jpg (Image is < 800x600, same as training)
# Processing: images/CIMG0133~2.JPG
# Processing: images/CIMG0579(2).JPG
# Processing: images/IMG_3701.JPG
#  -> Skipping images/IMG_3701.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3332(1).JPG
# Processing: images/CIMG0167.JPG
# Processing: images/CIMG0601.JPG
# Processing: images/CIMG0198.JPG
# Processing: images/DSC00096.JPG
# Processing: images/p24.jpg
# Processing: images/CIMG0371.JPG
# Processing: images/IMG_3477.JPG
#  -> Skipping images/IMG_3477.JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3338.JPG
# Processing: images/p19.jpg
# Processing: images/CIMG0402.JPG
# Processing: images/CIMG0364.JPG
# Processing: images/p25.jpg
# Processing: images/IMG_3674.JPG
#  -> Skipping images/IMG_3674.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0199.JPG
# Processing: images/IMG_20180724_170036332.jpg
# Processing: images/IMG_3700.JPG
#  -> Skipping images/IMG_3700.JPG (Image is < 800x600, same as training)
# Processing: images/CIMG0426~2.JPG
# Processing: images/IMG_20250524_140427028.jpg
# Processing: images/CIMG0209(1).JPG
# Processing: images/CIMG0006.JPG
# Processing: images/DSC_0359.JPG
# Processing: images/DSC00322.JPG
# Processing: images/CIMG0210.JPG
#  -> Skipping images/CIMG0210.JPG (Image is < 800x600, same as training)
# Processing: images/RIMG0066.JPG
# Processing: images/CIMG0200.JPG
# Processing: images/CIMG0572.JPG
# Processing: images/CIMG0228.JPG
# Processing: images/RIMG0076.JPG
# Processing: images/29032008701.jpg
# Processing: images/CIMG0599.JPG
# Processing: images/CIMG0002.JPG
# Processing: images/CIMG0297~2.JPG
# Processing: images/IMG_3410(1).JPG
# Processing: images/CIMG0980.jpg
# Processing: images/CIMG0604.JPG
# Processing: images/CIMG0162.JPG
# Processing: images/DSC02848.JPG
# Processing: images/CIMG0113~2.JPG
# Processing: images/CIMG0412.JPG
# Processing: images/100820081693.jpg
# Processing: images/IMG_20180724_170112733.jpg
# Processing: images/CIMG0137~2.JPG
# Processing: images/100820081692.jpg
# Processing: images/IMG_20180724_170028451.jpg
# Processing: images/CIMG0188.JPG
# Processing: images/CIMG0605.JPG
# Processing: images/CIMG0163.JPG
# Processing: images/IMG_3369(1).JPG
# Processing: images/CIMG0017.JPG
# Processing: images/DSC_0360.JPG
# Processing: images/CIMG0573.JPG
# Processing: images/CIMG0217.JPG
# Processing: images/DSC00319.JPG
# Processing: images/RIMG0075.JPG
# Processing: images/CIMG0079(1).JPG
# Processing: images/CIMG0015.JPG
# Processing: images/CIMG0067(1).JPG
# Processing: images/CIMG0029.JPG
# Processing: images/CIMG0108~2.JPG
# Processing: images/CIMG0209~2.JPG
# Processing: images/IMG_20211223_163150170_HDR.jpg
# Processing: images/CIMG0149.JPG
# Processing: images/IMG_20180726_154940261_BURST000_COVER_TOP.jpg
# Processing: images/CIMG0170~2.JPG
# Processing: images/IMG_20250524_143429630.jpg
# Processing: images/CIMG0090~2.JPG
# Processing: images/CIMG0111~2.JPG
# Processing: images/IMG_20250627_104711559_HDR.jpg
# Processing: images/CIMG0120(1).JPG
#  -> Skipping images/CIMG0120(1).JPG (Image is < 800x600, same as training)
# Processing: images/IMG_3699.JPG
#  -> Skipping images/IMG_3699.JPG (Image is < 800x600, same as training)
# Processing: images/141120142185.jpg
# Processing: images/CIMG0160.JPG
# Processing: images/IMG_3706.JPG
# Processing: images/CIMG0014.JPG
# Processing: images/CIMG0089~2.JPG
# Processing: images/IMG_4158(1).JPG
#
# --- Done ---
# All visualizations saved to: cluster_visualizations_3
